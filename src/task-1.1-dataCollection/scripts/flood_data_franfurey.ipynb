# %%
import requests
from pprint import pprint
from typing import Any, Dict

def fetch_disasters(api_url: str, payload: Dict[str, Any]) -> Dict[str, Any]:
    """
    Fetch disasters from ReliefWeb API using a POST request.

    :param api_url: URL of the ReliefWeb API endpoint.
    :param payload: JSON payload for the POST request.
    :return: Response JSON data from the API.
    """
    headers = {
        'Content-Type': 'application/json'
    }
    
    response = requests.post(url=api_url, json=payload, headers=headers)
    response.raise_for_status()  # Raise an exception for HTTP errors
    
    return response.json()

if __name__ == "__main__":
    api_url = "https://api.reliefweb.int/v1/disasters"
    payload = {
        "offset": 0,
        "limit": 20,
        "filter": {
            "conditions": [
                {
                    "field": "type.id",
                    "value": [
                        "4611", "4624", "4656"
                    ],
                    "operator": "OR"
                },
                {
                    "field": "country.id",
                    "value": "244"
                }
            ],
            "operator": "AND"
        },
        "preset": "latest",
        "profile": "list",
        "appname": "kesho_ai"
    }

    try:
        result = fetch_disasters(api_url=api_url, payload=payload)
        pprint(result)
    except requests.exceptions.RequestException as e:
        print("An error occurred:", e)
# Out:
# {'count': 20,
#  'data': [{'fields': {'country': [{'name': 'United Republic of Tanzania'}],
#                       'date': {'created': '2024-04-26T12:34:49+00:00'},
#                       'glide': 'FL-2024-000058-TZA',
#                       'name': 'Tanzania: Floods - Apr 2024',
#                       'status': 'ongoing',
#                       'type': [{'name': 'Flood'}, {'name': 'Land Slide'}],
#                       'url': 'https://reliefweb.int/taxonomy/term/51982'},
#            'href': 'https://api.reliefweb.int/v1/disasters/51982',
#            'id': '51982',
#            'score': 1},
#           {'fields': {'country': [{'name': 'United Republic of Tanzania'}],
#                       'date': {'created': '2023-11-16T13:00:50+00:00'},
#                       'glide': 'FL-2023-000241-TZA',
#                       'name': 'Tanzania: Floods - Nov 2023',
#                       'status': 'past',
#                       'type': [{'name': 'Flood'}],
#                       'url': 'https://reliefweb.int/taxonomy/term/51811'},
#            'href': 'https://api.reliefweb.int/v1/disasters/51811',
#            'id': '51811',
#            'score': 1},
#           {'fields': {'country': [{'name': 'United Republic of Tanzania'}],
#                       'date': {'created': '2023-04-17T08:12:38+00:00'},
#                       'glide': 'FL-2023-000056-TZA',
#                       'name': 'Tanzania: Floods - Apr 2023',
#                       'status': 'past',
#                       'type': [{'name': 'Flood'}],
#                       'url': 'https://reliefweb.int/taxonomy/term/51549'},
#            'href': 'https://api.reliefweb.int/v1/disasters/51549',
#            'id': '51549',
#            'score': 1},
#           {'fields': {'country': [{'name': 'Comoros'},
#                                   {'name': 'Madagascar'},
#                                   {'name': 'Seychelles'},
#                                   {'name': 'United Republic of Tanzania'}],
#                       'date': {'created': '2021-04-21T00:00:00+00:00'},
#                       'glide': 'TC-2021-000036-TZA',
#                       'name': 'Tropical Storm Jobo - Apr 2021',
#                       'status': 'past',
#                       'type': [{'name': 'Flash Flood'},
#                                {'name': 'Flood'},
#                                {'name': 'Tropical Cyclone'}],
#                       'url': 'https://reliefweb.int/taxonomy/term/50699'},
#            'href': 'https://api.reliefweb.int/v1/disasters/50699',
#            'id': '50699',
#            'score': 1},
#           {'fields': {'country': [{'name': 'United Republic of Tanzania'}],
#                       'date': {'created': '2020-04-24T00:00:00+00:00'},
#                       'glide': 'FL-2020-000125-TZA',
#                       'name': 'Tanzania: Floods - Apr 2020',
#                       'status': 'past',
#                       'type': [{'name': 'Flash Flood'},
#                                {'name': 'Flood'},
#                                {'name': 'Land Slide'}],
#                       'url': 'https://reliefweb.int/taxonomy/term/50286'},
#            'href': 'https://api.reliefweb.int/v1/disasters/50286',
#            'id': '50286',
#            'score': 1},
#           {'fields': {'country': [{'name': 'United Republic of Tanzania'}],
#                       'date': {'created': '2020-01-27T00:00:00+00:00'},
#                       'glide': 'FL-2020-000029-TZA',
#                       'name': 'Tanzania: Floods - Jan 2020',
#                       'status': 'past',
#                       'type': [{'name': 'Flash Flood'}, {'name': 'Flood'}],
#                       'url': 'https://reliefweb.int/taxonomy/term/49918'},
#            'href': 'https://api.reliefweb.int/v1/disasters/49918',
#            'id': '49918',
#            'score': 1},
#           {'fields': {'country': [{'name': 'United Republic of Tanzania'}],
#                       'date': {'created': '2019-10-16T00:00:00+00:00'},
#                       'glide': 'FL-2019-000145-TZA',
#                       'name': 'Tanzania: Floods - Oct 2019',
#                       'status': 'past',
#                       'type': [{'name': 'Flood'}],
#                       'url': 'https://reliefweb.int/taxonomy/term/49373'},
#            'href': 'https://api.reliefweb.int/v1/disasters/49373',
#            'id': '49373',
#            'score': 1},
#           {'fields': {'country': [{'name': 'United Republic of Tanzania'}],
#                       'date': {'created': '2019-05-08T00:00:00+00:00'},
#                       'glide': 'FL-2019-000048-TZA',
#                       'name': 'Tanzania: Floods - May 2019',
#                       'status': 'past',
#                       'type': [{'name': 'Flood'}],
#                       'url': 'https://reliefweb.int/taxonomy/term/48268'},
#            'href': 'https://api.reliefweb.int/v1/disasters/48268',
#            'id': '48268',
#            'score': 1},
#           {'fields': {'country': [{'name': 'Comoros'},
#                                   {'name': 'Madagascar'},
#                                   {'name': 'Malawi'},
#                                   {'name': 'Mozambique'},
#                                   {'name': 'United Republic of Tanzania'}],
#                       'date': {'created': '2019-04-23T00:00:00+00:00'},
#                       'glide': 'TC-2019-000038-MOZ',
#                       'name': 'Tropical Cyclone Kenneth - Apr 2019',
#                       'status': 'past',
#                       'type': [{'name': 'Flood'},
#                                {'name': 'Land Slide'},
#                                {'name': 'Tropical Cyclone'}],
#                       'url': 'https://reliefweb.int/taxonomy/term/48078'},
#            'href': 'https://api.reliefweb.int/v1/disasters/48078',
#            'id': '48078',
#            'score': 1},
#           {'fields': {'country': [{'name': 'United Republic of Tanzania'}],
#                       'date': {'created': '2018-04-18T00:00:00+00:00'},
#                       'glide': 'FL-2018-000043-TZA',
#                       'name': 'Tanzania: Floods - Apr 2018',
#                       'status': 'past',
#                       'type': [{'name': 'Flood'}],
#                       'url': 'https://reliefweb.int/taxonomy/term/45654'},
#            'href': 'https://api.reliefweb.int/v1/disasters/45654',
#            'id': '45654',
#            'score': 1},
#           {'fields': {'country': [{'name': 'United Republic of Tanzania'}],
#                       'date': {'created': '2016-01-31T00:00:00+00:00'},
#                       'glide': 'FL-2016-000011-TZA',
#                       'name': 'Tanzania: Floods - Jan 2016',
#                       'status': 'past',
#                       'type': [{'name': 'Flood'}],
#                       'url': 'https://reliefweb.int/taxonomy/term/30541'},
#            'href': 'https://api.reliefweb.int/v1/disasters/30541',
#            'id': '30541',
#            'score': 1},
#           {'fields': {'country': [{'name': 'United Republic of Tanzania'}],
#                       'date': {'created': '2015-03-03T00:00:00+00:00'},
#                       'glide': 'ST-2015-000019-TZA',
#                       'name': 'Tanzania: Hail Storms - Mar 2015',
#                       'status': 'past',
#                       'type': [{'name': 'Flash Flood'},
#                                {'name': 'Flood'},
#                                {'name': 'Severe Local Storm'}],
#                       'url': 'https://reliefweb.int/taxonomy/term/19396'},
#            'href': 'https://api.reliefweb.int/v1/disasters/19396',
#            'id': '19396',
#            'score': 1},
#           {'fields': {'country': [{'name': 'United Republic of Tanzania'}],
#                       'date': {'created': '2014-04-15T00:00:00+00:00'},
#                       'glide': 'FL-2014-000053-TZA',
#                       'name': 'Tanzania: Floods - Apr 2014',
#                       'status': 'past',
#                       'type': [{'name': 'Flash Flood'}, {'name': 'Flood'}],
#                       'url': 'https://reliefweb.int/taxonomy/term/14501'},
#            'href': 'https://api.reliefweb.int/v1/disasters/14501',
#            'id': '14501',
#            'score': 1},
#           {'fields': {'country': [{'name': 'United Republic of Tanzania'}],
#                       'date': {'created': '2014-02-01T00:00:00+00:00'},
#                       'glide': 'FF-2014-000009-TZA',
#                       'name': 'Tanzania: Flash Floods - Jan 2014',
#                       'status': 'past',
#                       'type': [{'name': 'Flash Flood'}, {'name': 'Flood'}],
#                       'url': 'https://reliefweb.int/taxonomy/term/14001'},
#            'href': 'https://api.reliefweb.int/v1/disasters/14001',
#            'id': '14001',
#            'score': 1},
#           {'fields': {'country': [{'name': 'United Republic of Tanzania'}],
#                       'date': {'created': '2011-12-03T00:00:00+00:00'},
#                       'glide': 'FL-2011-000183-TZA',
#                       'name': 'Tanzania: Floods and Landslides - Dec 2011',
#                       'status': 'past',
#                       'type': [{'name': 'Flood'}],
#                       'url': 'https://reliefweb.int/taxonomy/term/9698'},
#            'href': 'https://api.reliefweb.int/v1/disasters/9698',
#            'id': '9698',
#            'score': 1},
#           {'fields': {'country': [{'name': 'Burundi'},
#                                   {'name': 'Kenya'},
#                                   {'name': 'Rwanda'},
#                                   {'name': 'Uganda'},
#                                   {'name': 'United Republic of Tanzania'}],
#                       'date': {'created': '2010-03-17T00:00:00+00:00'},
#                       'glide': 'LS-2010-000040-UGA',
#                       'name': 'East Africa: Floods - Mar 2010',
#                       'status': 'past',
#                       'type': [{'name': 'Flood'}],
#                       'url': 'https://reliefweb.int/taxonomy/term/6758'},
#            'href': 'https://api.reliefweb.int/v1/disasters/6758',
#            'id': '6758',
#            'score': 1},
#           {'fields': {'country': [{'name': 'United Republic of Tanzania'}],
#                       'date': {'created': '2008-01-23T00:00:00+00:00'},
#                       'glide': 'FL-2008-000011-TZA',
#                       'name': 'Tanzania: Floods - Jan 2008',
#                       'status': 'past',
#                       'type': [{'name': 'Flood'}],
#                       'url': 'https://reliefweb.int/taxonomy/term/4645'},
#            'href': 'https://api.reliefweb.int/v1/disasters/4645',
#            'id': '4645',
#            'score': 1},
#           {'fields': {'country': [{'name': 'United Republic of Tanzania'}],
#                       'date': {'created': '2006-11-13T00:00:00+00:00'},
#                       'glide': 'FL-2006-000164-TZA',
#                       'name': 'Tanzania: Heavy Rains - Nov 2006',
#                       'status': 'past',
#                       'type': [{'name': 'Flood'}],
#                       'url': 'https://reliefweb.int/taxonomy/term/4693'},
#            'href': 'https://api.reliefweb.int/v1/disasters/4693',
#            'id': '4693',
#            'score': 1},
#           {'fields': {'country': [{'name': 'United Republic of Tanzania'}],
#                       'date': {'created': '2006-05-15T00:00:00+00:00'},
#                       'glide': 'FL-2006-000065-TZA',
#                       'name': 'Tanzania: Floods - May 2006',
#                       'status': 'past',
#                       'type': [{'name': 'Flood'}],
#                       'url': 'https://reliefweb.int/taxonomy/term/6590'},
#            'href': 'https://api.reliefweb.int/v1/disasters/6590',
#            'id': '6590',
#            'score': 1},
#           {'fields': {'country': [{'name': 'United Republic of Tanzania'}],
#                       'date': {'created': '2005-04-22T00:00:00+00:00'},
#                       'glide': 'FL-2005-000062-TZA',
#                       'name': 'Tanzania: Floods - Apr 2005',
#                       'status': 'past',
#                       'type': [{'name': 'Flood'}],
#                       'url': 'https://reliefweb.int/taxonomy/term/5901'},
#            'href': 'https://api.reliefweb.int/v1/disasters/5901',
#            'id': '5901',
#            'score': 1}],
#  'href': 'https://api.reliefweb.int/v1/disasters',
#  'links': {'next': {'href': 'https://api.reliefweb.int/v1/disasters?offset=20&limit=20'},
#            'self': {'href': 'https://api.reliefweb.int/v1/disasters'}},
#  'time': 19,
#  'took': 12,
#  'totalCount': 27}
