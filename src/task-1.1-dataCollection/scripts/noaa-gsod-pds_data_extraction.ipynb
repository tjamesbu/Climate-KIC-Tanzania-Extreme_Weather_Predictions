# %% [markdown]
# # Data source: https://registry.opendata.aws/noaa-gsod/

# %%
import time
import s3fs
import pandas as pd

# %%
# Initialize the S3 filesystem object with the connection parameters
fs = s3fs.S3FileSystem(anon=True, client_kwargs={'region_name': 'us-east-1'})
# Specify the S3 path to the file you want to access

# %%
# Defining initial path with current year to check available weather stations 
s3_path = "s3://noaa-gsod-pds/2024/"

# %%
# List the objects in the bucket with the specified prefix (current year)
try:
    files = fs.ls(s3_path)
except Exception as e:
    print("Error:", e)

# %%
files[:5]
# Out:
# ['noaa-gsod-pds/2024/01001099999.csv',
#  'noaa-gsod-pds/2024/01001499999.csv',
#  'noaa-gsod-pds/2024/01002099999.csv',
#  'noaa-gsod-pds/2024/01003099999.csv',
#  'noaa-gsod-pds/2024/01006099999.csv']

# %%
# Opening every file contained in the bucket (current year) with pandas and saving it in an array 
# Let's check how long it takes
start_time = time.time()

dfs = []
for file in files:
    with fs.open(file, mode='rb') as f:
        data = pd.read_csv(f)
    dfs.append(data)
    
end_time = time.time()
end_time - start_time
# Out:
# 2039.7869002819061

# %% [markdown]
# ### As you can see in the previous printing, the previous process took some time (~ 30min)

# %%
# concatenating all data frames (from 2024) in the dfs array as a unique data frame 
gsod = pd.concat(dfs, ignore_index=True)

# %%
# Size of the data frame for 2024
gsod.shape[0]
# Out:
# 1931730

# %% [markdown]
# ### Let's check the latitude and the longitude of the data to see if Tanzania's longitude and latitud is in the range

# %%
# Tanzania's longitude ~ 35
gsod['LONGITUDE'].min(), gsod['LONGITUDE'].max()
# Out:
# (-179.9833333, 179.75)

# %%
# Tanzania's latitude ~ -6
(gsod['LATITUDE'].min(), gsod['LATITUDE'].max())
# Out:
# (-90.0, 83.65)

# %% [markdown]
# ### Checking the name of the stations I could get the number of the stations. This will be useful to get the data (the csv files are named after the stations, ex: 063729099999.csv)

# %%
# Saving the station's name to get the data
stations = (gsod[gsod['NAME'].astype(str).str.contains(" TZ")]["STATION"].unique())
stations
# Out:
# array([63729099999, 63733099999, 63756099999, 63789099999, 63791099999,
#        63801099999, 63832099999, 63845099999, 63862099999, 63866099999,
#        63870099999, 63881099999, 63887099999, 63894099999, 63962099999,
#        63971099999], dtype=object)

# %% [markdown]
# ### Now let's repeat the process for the whole content in the s3 bucket to obtain all the data from Tanzania for every available year

# %%
# s3 bucket path
s3_path = "s3://noaa-gsod-pds/"

# %%
start = time.time()

# Navigate through all the folders in the bucket and get the data from Tanzania
try:
    files = []
    dfs = []
    folders = fs.ls(s3_path)
    folders.pop()

    # Filter out only CSV files
    for i, folder in enumerate(folders):
        for j, station in enumerate(stations):
            file = folder+"/"+str(station)+".csv"
            files.append(file)
            try:
                with fs.open(file, mode='rb') as f:
                    data = pd.read_csv(f)
                dfs.append(data)
            except Exception as a:
                # It will print the file name of the stations whose data is not contained in the given year
                print("File", a, " not in database") 
                pass    
            
        
except Exception as e:
    print("Error:", e)

end = time.time()

print(end - start)
# Out:
# File noaa-gsod-pds/1929/63729099999.csv  not in database
# File noaa-gsod-pds/1929/63733099999.csv  not in database
# File noaa-gsod-pds/1929/63756099999.csv  not in database
# File noaa-gsod-pds/1929/63789099999.csv  not in database
# File noaa-gsod-pds/1929/63791099999.csv  not in database
# File noaa-gsod-pds/1929/63801099999.csv  not in database
# File noaa-gsod-pds/1929/63832099999.csv  not in database
# File noaa-gsod-pds/1929/63845099999.csv  not in database
# File noaa-gsod-pds/1929/63862099999.csv  not in database
# File noaa-gsod-pds/1929/63866099999.csv  not in database
# File noaa-gsod-pds/1929/63870099999.csv  not in database
# File noaa-gsod-pds/1929/63881099999.csv  not in database
# File noaa-gsod-pds/1929/63887099999.csv  not in database
# File noaa-gsod-pds/1929/63894099999.csv  not in database
# File noaa-gsod-pds/1929/63962099999.csv  not in database
# File noaa-gsod-pds/1929/63971099999.csv  not in database
# File noaa-gsod-pds/1930/63729099999.csv  not in database
# File noaa-gsod-pds/1930/63733099999.csv  not in database
# File noaa-gsod-pds/1930/63756099999.csv  not in database
# File noaa-gsod-pds/1930/63789099999.csv  not in database
# File noaa-gsod-pds/1930/63791099999.csv  not in database
# File noaa-gsod-pds/1930/63801099999.csv  not in database
# File noaa-gsod-pds/1930/63832099999.csv  not in database
# File noaa-gsod-pds/1930/63845099999.csv  not in database
# File noaa-gsod-pds/1930/63862099999.csv  not in database
# File noaa-gsod-pds/1930/63866099999.csv  not in database
# File noaa-gsod-pds/1930/63870099999.csv  not in database
# File noaa-gsod-pds/1930/63881099999.csv  not in database
# File noaa-gsod-pds/1930/63887099999.csv  not in database
# File noaa-gsod-pds/1930/63894099999.csv  not in database
# File noaa-gsod-pds/1930/63962099999.csv  not in database
# File noaa-gsod-pds/1930/63971099999.csv  not in database
# File noaa-gsod-pds/1931/63729099999.csv  not in database
# File noaa-gsod-pds/1931/63733099999.csv  not in database
# File noaa-gsod-pds/1931/63756099999.csv  not in database
# File noaa-gsod-pds/1931/63789099999.csv  not in database
# File noaa-gsod-pds/1931/63791099999.csv  not in database
# File noaa-gsod-pds/1931/63801099999.csv  not in database
# File noaa-gsod-pds/1931/63832099999.csv  not in database
# File noaa-gsod-pds/1931/63845099999.csv  not in database
# File noaa-gsod-pds/1931/63862099999.csv  not in database
# File noaa-gsod-pds/1931/63866099999.csv  not in database
# File noaa-gsod-pds/1931/63870099999.csv  not in database
# File noaa-gsod-pds/1931/63881099999.csv  not in database
# File noaa-gsod-pds/1931/63887099999.csv  not in database
# File noaa-gsod-pds/1931/63894099999.csv  not in database
# File noaa-gsod-pds/1931/63962099999.csv  not in database
# File noaa-gsod-pds/1931/63971099999.csv  not in database
# File noaa-gsod-pds/1932/63729099999.csv  not in database
# File noaa-gsod-pds/1932/63733099999.csv  not in database
# File noaa-gsod-pds/1932/63756099999.csv  not in database
# File noaa-gsod-pds/1932/63789099999.csv  not in database
# File noaa-gsod-pds/1932/63791099999.csv  not in database
# File noaa-gsod-pds/1932/63801099999.csv  not in database
# File noaa-gsod-pds/1932/63832099999.csv  not in database
# File noaa-gsod-pds/1932/63845099999.csv  not in database
# File noaa-gsod-pds/1932/63862099999.csv  not in database
# File noaa-gsod-pds/1932/63866099999.csv  not in database
# File noaa-gsod-pds/1932/63870099999.csv  not in database
# File noaa-gsod-pds/1932/63881099999.csv  not in database
# File noaa-gsod-pds/1932/63887099999.csv  not in database
# File noaa-gsod-pds/1932/63894099999.csv  not in database
# File noaa-gsod-pds/1932/63962099999.csv  not in database
# File noaa-gsod-pds/1932/63971099999.csv  not in database
# File noaa-gsod-pds/1933/63729099999.csv  not in database
# File noaa-gsod-pds/1933/63733099999.csv  not in database
# File noaa-gsod-pds/1933/63756099999.csv  not in database
# File noaa-gsod-pds/1933/63789099999.csv  not in database
# File noaa-gsod-pds/1933/63791099999.csv  not in database
# File noaa-gsod-pds/1933/63801099999.csv  not in database
# File noaa-gsod-pds/1933/63832099999.csv  not in database
# File noaa-gsod-pds/1933/63845099999.csv  not in database
# File noaa-gsod-pds/1933/63862099999.csv  not in database
# File noaa-gsod-pds/1933/63866099999.csv  not in database
# File noaa-gsod-pds/1933/63870099999.csv  not in database
# File noaa-gsod-pds/1933/63881099999.csv  not in database
# File noaa-gsod-pds/1933/63887099999.csv  not in database
# File noaa-gsod-pds/1933/63894099999.csv  not in database
# File noaa-gsod-pds/1933/63962099999.csv  not in database
# File noaa-gsod-pds/1933/63971099999.csv  not in database
# File noaa-gsod-pds/1934/63729099999.csv  not in database
# File noaa-gsod-pds/1934/63733099999.csv  not in database
# File noaa-gsod-pds/1934/63756099999.csv  not in database
# File noaa-gsod-pds/1934/63789099999.csv  not in database
# File noaa-gsod-pds/1934/63791099999.csv  not in database
# File noaa-gsod-pds/1934/63801099999.csv  not in database
# File noaa-gsod-pds/1934/63832099999.csv  not in database
# File noaa-gsod-pds/1934/63845099999.csv  not in database
# File noaa-gsod-pds/1934/63862099999.csv  not in database
# File noaa-gsod-pds/1934/63866099999.csv  not in database
# File noaa-gsod-pds/1934/63870099999.csv  not in database
# File noaa-gsod-pds/1934/63881099999.csv  not in database
# File noaa-gsod-pds/1934/63887099999.csv  not in database
# File noaa-gsod-pds/1934/63894099999.csv  not in database
# File noaa-gsod-pds/1934/63962099999.csv  not in database
# File noaa-gsod-pds/1934/63971099999.csv  not in database
# File noaa-gsod-pds/1935/63729099999.csv  not in database
# File noaa-gsod-pds/1935/63733099999.csv  not in database
# File noaa-gsod-pds/1935/63756099999.csv  not in database
# File noaa-gsod-pds/1935/63789099999.csv  not in database
# File noaa-gsod-pds/1935/63791099999.csv  not in database
# File noaa-gsod-pds/1935/63801099999.csv  not in database
# File noaa-gsod-pds/1935/63832099999.csv  not in database
# File noaa-gsod-pds/1935/63845099999.csv  not in database
# File noaa-gsod-pds/1935/63862099999.csv  not in database
# File noaa-gsod-pds/1935/63866099999.csv  not in database
# File noaa-gsod-pds/1935/63870099999.csv  not in database
# File noaa-gsod-pds/1935/63881099999.csv  not in database
# File noaa-gsod-pds/1935/63887099999.csv  not in database
# File noaa-gsod-pds/1935/63894099999.csv  not in database
# File noaa-gsod-pds/1935/63962099999.csv  not in database
# File noaa-gsod-pds/1935/63971099999.csv  not in database
# File noaa-gsod-pds/1936/63729099999.csv  not in database
# File noaa-gsod-pds/1936/63733099999.csv  not in database
# File noaa-gsod-pds/1936/63756099999.csv  not in database
# File noaa-gsod-pds/1936/63789099999.csv  not in database
# File noaa-gsod-pds/1936/63791099999.csv  not in database
# File noaa-gsod-pds/1936/63801099999.csv  not in database
# File noaa-gsod-pds/1936/63832099999.csv  not in database
# File noaa-gsod-pds/1936/63845099999.csv  not in database
# File noaa-gsod-pds/1936/63862099999.csv  not in database
# File noaa-gsod-pds/1936/63866099999.csv  not in database
# File noaa-gsod-pds/1936/63870099999.csv  not in database
# File noaa-gsod-pds/1936/63881099999.csv  not in database
# File noaa-gsod-pds/1936/63887099999.csv  not in database
# File noaa-gsod-pds/1936/63894099999.csv  not in database
# File noaa-gsod-pds/1936/63962099999.csv  not in database
# File noaa-gsod-pds/1936/63971099999.csv  not in database
# File noaa-gsod-pds/1937/63729099999.csv  not in database
# File noaa-gsod-pds/1937/63733099999.csv  not in database
# File noaa-gsod-pds/1937/63756099999.csv  not in database
# File noaa-gsod-pds/1937/63789099999.csv  not in database
# File noaa-gsod-pds/1937/63791099999.csv  not in database
# File noaa-gsod-pds/1937/63801099999.csv  not in database
# File noaa-gsod-pds/1937/63832099999.csv  not in database
# File noaa-gsod-pds/1937/63845099999.csv  not in database
# File noaa-gsod-pds/1937/63862099999.csv  not in database
# File noaa-gsod-pds/1937/63866099999.csv  not in database
# File noaa-gsod-pds/1937/63870099999.csv  not in database
# File noaa-gsod-pds/1937/63881099999.csv  not in database
# File noaa-gsod-pds/1937/63887099999.csv  not in database
# File noaa-gsod-pds/1937/63894099999.csv  not in database
# File noaa-gsod-pds/1937/63962099999.csv  not in database
# File noaa-gsod-pds/1937/63971099999.csv  not in database
# File noaa-gsod-pds/1938/63729099999.csv  not in database
# File noaa-gsod-pds/1938/63733099999.csv  not in database
# File noaa-gsod-pds/1938/63756099999.csv  not in database
# File noaa-gsod-pds/1938/63789099999.csv  not in database
# File noaa-gsod-pds/1938/63791099999.csv  not in database
# File noaa-gsod-pds/1938/63801099999.csv  not in database
# File noaa-gsod-pds/1938/63832099999.csv  not in database
# File noaa-gsod-pds/1938/63845099999.csv  not in database
# File noaa-gsod-pds/1938/63862099999.csv  not in database
# File noaa-gsod-pds/1938/63866099999.csv  not in database
# File noaa-gsod-pds/1938/63870099999.csv  not in database
# File noaa-gsod-pds/1938/63881099999.csv  not in database
# File noaa-gsod-pds/1938/63887099999.csv  not in database
# File noaa-gsod-pds/1938/63894099999.csv  not in database
# File noaa-gsod-pds/1938/63962099999.csv  not in database
# File noaa-gsod-pds/1938/63971099999.csv  not in database
# File noaa-gsod-pds/1939/63729099999.csv  not in database
# File noaa-gsod-pds/1939/63733099999.csv  not in database
# File noaa-gsod-pds/1939/63756099999.csv  not in database
# File noaa-gsod-pds/1939/63789099999.csv  not in database
# File noaa-gsod-pds/1939/63791099999.csv  not in database
# File noaa-gsod-pds/1939/63801099999.csv  not in database
# File noaa-gsod-pds/1939/63832099999.csv  not in database
# File noaa-gsod-pds/1939/63845099999.csv  not in database
# File noaa-gsod-pds/1939/63862099999.csv  not in database
# File noaa-gsod-pds/1939/63866099999.csv  not in database
# File noaa-gsod-pds/1939/63870099999.csv  not in database
# File noaa-gsod-pds/1939/63881099999.csv  not in database
# File noaa-gsod-pds/1939/63887099999.csv  not in database
# File noaa-gsod-pds/1939/63894099999.csv  not in database
# File noaa-gsod-pds/1939/63962099999.csv  not in database
# File noaa-gsod-pds/1939/63971099999.csv  not in database
# File noaa-gsod-pds/1940/63729099999.csv  not in database
# File noaa-gsod-pds/1940/63733099999.csv  not in database
# File noaa-gsod-pds/1940/63756099999.csv  not in database
# File noaa-gsod-pds/1940/63789099999.csv  not in database
# File noaa-gsod-pds/1940/63791099999.csv  not in database
# File noaa-gsod-pds/1940/63801099999.csv  not in database
# File noaa-gsod-pds/1940/63832099999.csv  not in database
# File noaa-gsod-pds/1940/63845099999.csv  not in database
# File noaa-gsod-pds/1940/63862099999.csv  not in database
# File noaa-gsod-pds/1940/63866099999.csv  not in database
# File noaa-gsod-pds/1940/63870099999.csv  not in database
# File noaa-gsod-pds/1940/63881099999.csv  not in database
# File noaa-gsod-pds/1940/63887099999.csv  not in database
# File noaa-gsod-pds/1940/63894099999.csv  not in database
# File noaa-gsod-pds/1940/63962099999.csv  not in database
# File noaa-gsod-pds/1940/63971099999.csv  not in database
# File noaa-gsod-pds/1941/63729099999.csv  not in database
# File noaa-gsod-pds/1941/63733099999.csv  not in database
# File noaa-gsod-pds/1941/63756099999.csv  not in database
# File noaa-gsod-pds/1941/63789099999.csv  not in database
# File noaa-gsod-pds/1941/63791099999.csv  not in database
# File noaa-gsod-pds/1941/63801099999.csv  not in database
# File noaa-gsod-pds/1941/63832099999.csv  not in database
# File noaa-gsod-pds/1941/63845099999.csv  not in database
# File noaa-gsod-pds/1941/63862099999.csv  not in database
# File noaa-gsod-pds/1941/63866099999.csv  not in database
# File noaa-gsod-pds/1941/63870099999.csv  not in database
# File noaa-gsod-pds/1941/63881099999.csv  not in database
# File noaa-gsod-pds/1941/63887099999.csv  not in database
# File noaa-gsod-pds/1941/63894099999.csv  not in database
# File noaa-gsod-pds/1941/63962099999.csv  not in database
# File noaa-gsod-pds/1941/63971099999.csv  not in database
# File noaa-gsod-pds/1942/63729099999.csv  not in database
# File noaa-gsod-pds/1942/63733099999.csv  not in database
# File noaa-gsod-pds/1942/63756099999.csv  not in database
# File noaa-gsod-pds/1942/63789099999.csv  not in database
# File noaa-gsod-pds/1942/63791099999.csv  not in database
# File noaa-gsod-pds/1942/63801099999.csv  not in database
# File noaa-gsod-pds/1942/63832099999.csv  not in database
# File noaa-gsod-pds/1942/63845099999.csv  not in database
# File noaa-gsod-pds/1942/63862099999.csv  not in database
# File noaa-gsod-pds/1942/63866099999.csv  not in database
# File noaa-gsod-pds/1942/63870099999.csv  not in database
# File noaa-gsod-pds/1942/63881099999.csv  not in database
# File noaa-gsod-pds/1942/63887099999.csv  not in database
# File noaa-gsod-pds/1942/63894099999.csv  not in database
# File noaa-gsod-pds/1942/63962099999.csv  not in database
# File noaa-gsod-pds/1942/63971099999.csv  not in database
# File noaa-gsod-pds/1943/63729099999.csv  not in database
# File noaa-gsod-pds/1943/63733099999.csv  not in database
# File noaa-gsod-pds/1943/63756099999.csv  not in database
# File noaa-gsod-pds/1943/63789099999.csv  not in database
# File noaa-gsod-pds/1943/63791099999.csv  not in database
# File noaa-gsod-pds/1943/63801099999.csv  not in database
# File noaa-gsod-pds/1943/63832099999.csv  not in database
# File noaa-gsod-pds/1943/63845099999.csv  not in database
# File noaa-gsod-pds/1943/63862099999.csv  not in database
# File noaa-gsod-pds/1943/63866099999.csv  not in database
# File noaa-gsod-pds/1943/63870099999.csv  not in database
# File noaa-gsod-pds/1943/63881099999.csv  not in database
# File noaa-gsod-pds/1943/63887099999.csv  not in database
# File noaa-gsod-pds/1943/63894099999.csv  not in database
# File noaa-gsod-pds/1943/63962099999.csv  not in database
# File noaa-gsod-pds/1943/63971099999.csv  not in database
# File noaa-gsod-pds/1944/63729099999.csv  not in database
# File noaa-gsod-pds/1944/63733099999.csv  not in database
# File noaa-gsod-pds/1944/63756099999.csv  not in database
# File noaa-gsod-pds/1944/63789099999.csv  not in database
# File noaa-gsod-pds/1944/63791099999.csv  not in database
# File noaa-gsod-pds/1944/63801099999.csv  not in database
# File noaa-gsod-pds/1944/63832099999.csv  not in database
# File noaa-gsod-pds/1944/63845099999.csv  not in database
# File noaa-gsod-pds/1944/63862099999.csv  not in database
# File noaa-gsod-pds/1944/63866099999.csv  not in database
# File noaa-gsod-pds/1944/63870099999.csv  not in database
# File noaa-gsod-pds/1944/63881099999.csv  not in database
# File noaa-gsod-pds/1944/63887099999.csv  not in database
# File noaa-gsod-pds/1944/63894099999.csv  not in database
# File noaa-gsod-pds/1944/63962099999.csv  not in database
# File noaa-gsod-pds/1944/63971099999.csv  not in database
# File noaa-gsod-pds/1945/63729099999.csv  not in database
# File noaa-gsod-pds/1945/63733099999.csv  not in database
# File noaa-gsod-pds/1945/63756099999.csv  not in database
# File noaa-gsod-pds/1945/63789099999.csv  not in database
# File noaa-gsod-pds/1945/63791099999.csv  not in database
# File noaa-gsod-pds/1945/63801099999.csv  not in database
# File noaa-gsod-pds/1945/63832099999.csv  not in database
# File noaa-gsod-pds/1945/63845099999.csv  not in database
# File noaa-gsod-pds/1945/63862099999.csv  not in database
# File noaa-gsod-pds/1945/63866099999.csv  not in database
# File noaa-gsod-pds/1945/63870099999.csv  not in database
# File noaa-gsod-pds/1945/63881099999.csv  not in database
# File noaa-gsod-pds/1945/63887099999.csv  not in database
# File noaa-gsod-pds/1945/63894099999.csv  not in database
# File noaa-gsod-pds/1945/63962099999.csv  not in database
# File noaa-gsod-pds/1945/63971099999.csv  not in database
# File noaa-gsod-pds/1946/63729099999.csv  not in database
# File noaa-gsod-pds/1946/63733099999.csv  not in database
# File noaa-gsod-pds/1946/63756099999.csv  not in database
# File noaa-gsod-pds/1946/63789099999.csv  not in database
# File noaa-gsod-pds/1946/63791099999.csv  not in database
# File noaa-gsod-pds/1946/63801099999.csv  not in database
# File noaa-gsod-pds/1946/63832099999.csv  not in database
# File noaa-gsod-pds/1946/63845099999.csv  not in database
# File noaa-gsod-pds/1946/63862099999.csv  not in database
# File noaa-gsod-pds/1946/63866099999.csv  not in database
# File noaa-gsod-pds/1946/63870099999.csv  not in database
# File noaa-gsod-pds/1946/63881099999.csv  not in database
# File noaa-gsod-pds/1946/63887099999.csv  not in database
# File noaa-gsod-pds/1946/63894099999.csv  not in database
# File noaa-gsod-pds/1946/63962099999.csv  not in database
# File noaa-gsod-pds/1946/63971099999.csv  not in database
# File noaa-gsod-pds/1947/63729099999.csv  not in database
# File noaa-gsod-pds/1947/63733099999.csv  not in database
# File noaa-gsod-pds/1947/63756099999.csv  not in database
# File noaa-gsod-pds/1947/63789099999.csv  not in database
# File noaa-gsod-pds/1947/63791099999.csv  not in database
# File noaa-gsod-pds/1947/63801099999.csv  not in database
# File noaa-gsod-pds/1947/63832099999.csv  not in database
# File noaa-gsod-pds/1947/63845099999.csv  not in database
# File noaa-gsod-pds/1947/63862099999.csv  not in database
# File noaa-gsod-pds/1947/63866099999.csv  not in database
# File noaa-gsod-pds/1947/63870099999.csv  not in database
# File noaa-gsod-pds/1947/63881099999.csv  not in database
# File noaa-gsod-pds/1947/63887099999.csv  not in database
# File noaa-gsod-pds/1947/63894099999.csv  not in database
# File noaa-gsod-pds/1947/63962099999.csv  not in database
# File noaa-gsod-pds/1947/63971099999.csv  not in database
# File noaa-gsod-pds/1948/63729099999.csv  not in database
# File noaa-gsod-pds/1948/63733099999.csv  not in database
# File noaa-gsod-pds/1948/63756099999.csv  not in database
# File noaa-gsod-pds/1948/63789099999.csv  not in database
# File noaa-gsod-pds/1948/63791099999.csv  not in database
# File noaa-gsod-pds/1948/63801099999.csv  not in database
# File noaa-gsod-pds/1948/63832099999.csv  not in database
# File noaa-gsod-pds/1948/63845099999.csv  not in database
# File noaa-gsod-pds/1948/63862099999.csv  not in database
# File noaa-gsod-pds/1948/63866099999.csv  not in database
# File noaa-gsod-pds/1948/63870099999.csv  not in database
# File noaa-gsod-pds/1948/63881099999.csv  not in database
# File noaa-gsod-pds/1948/63887099999.csv  not in database
# File noaa-gsod-pds/1948/63894099999.csv  not in database
# File noaa-gsod-pds/1948/63962099999.csv  not in database
# File noaa-gsod-pds/1948/63971099999.csv  not in database
# File noaa-gsod-pds/1949/63729099999.csv  not in database
# File noaa-gsod-pds/1949/63733099999.csv  not in database
# File noaa-gsod-pds/1949/63756099999.csv  not in database
# File noaa-gsod-pds/1949/63789099999.csv  not in database
# File noaa-gsod-pds/1949/63791099999.csv  not in database
# File noaa-gsod-pds/1949/63801099999.csv  not in database
# File noaa-gsod-pds/1949/63832099999.csv  not in database
# File noaa-gsod-pds/1949/63845099999.csv  not in database
# File noaa-gsod-pds/1949/63862099999.csv  not in database
# File noaa-gsod-pds/1949/63866099999.csv  not in database
# File noaa-gsod-pds/1949/63870099999.csv  not in database
# File noaa-gsod-pds/1949/63881099999.csv  not in database
# File noaa-gsod-pds/1949/63887099999.csv  not in database
# File noaa-gsod-pds/1949/63894099999.csv  not in database
# File noaa-gsod-pds/1949/63962099999.csv  not in database
# File noaa-gsod-pds/1949/63971099999.csv  not in database
# File noaa-gsod-pds/1950/63729099999.csv  not in database
# File noaa-gsod-pds/1950/63733099999.csv  not in database
# File noaa-gsod-pds/1950/63756099999.csv  not in database
# File noaa-gsod-pds/1950/63789099999.csv  not in database
# File noaa-gsod-pds/1950/63791099999.csv  not in database
# File noaa-gsod-pds/1950/63801099999.csv  not in database
# File noaa-gsod-pds/1950/63832099999.csv  not in database
# File noaa-gsod-pds/1950/63845099999.csv  not in database
# File noaa-gsod-pds/1950/63862099999.csv  not in database
# File noaa-gsod-pds/1950/63866099999.csv  not in database
# File noaa-gsod-pds/1950/63870099999.csv  not in database
# File noaa-gsod-pds/1950/63881099999.csv  not in database
# File noaa-gsod-pds/1950/63887099999.csv  not in database
# File noaa-gsod-pds/1950/63894099999.csv  not in database
# File noaa-gsod-pds/1950/63962099999.csv  not in database
# File noaa-gsod-pds/1950/63971099999.csv  not in database
# File noaa-gsod-pds/1951/63729099999.csv  not in database
# File noaa-gsod-pds/1951/63733099999.csv  not in database
# File noaa-gsod-pds/1951/63756099999.csv  not in database
# File noaa-gsod-pds/1951/63789099999.csv  not in database
# File noaa-gsod-pds/1951/63791099999.csv  not in database
# File noaa-gsod-pds/1951/63801099999.csv  not in database
# File noaa-gsod-pds/1951/63832099999.csv  not in database
# File noaa-gsod-pds/1951/63845099999.csv  not in database
# File noaa-gsod-pds/1951/63862099999.csv  not in database
# File noaa-gsod-pds/1951/63866099999.csv  not in database
# File noaa-gsod-pds/1951/63870099999.csv  not in database
# File noaa-gsod-pds/1951/63881099999.csv  not in database
# File noaa-gsod-pds/1951/63887099999.csv  not in database
# File noaa-gsod-pds/1951/63894099999.csv  not in database
# File noaa-gsod-pds/1951/63962099999.csv  not in database
# File noaa-gsod-pds/1951/63971099999.csv  not in database
# File noaa-gsod-pds/1952/63729099999.csv  not in database
# File noaa-gsod-pds/1952/63733099999.csv  not in database
# File noaa-gsod-pds/1952/63756099999.csv  not in database
# File noaa-gsod-pds/1952/63789099999.csv  not in database
# File noaa-gsod-pds/1952/63791099999.csv  not in database
# File noaa-gsod-pds/1952/63801099999.csv  not in database
# File noaa-gsod-pds/1952/63832099999.csv  not in database
# File noaa-gsod-pds/1952/63845099999.csv  not in database
# File noaa-gsod-pds/1952/63862099999.csv  not in database
# File noaa-gsod-pds/1952/63866099999.csv  not in database
# File noaa-gsod-pds/1952/63870099999.csv  not in database
# File noaa-gsod-pds/1952/63881099999.csv  not in database
# File noaa-gsod-pds/1952/63887099999.csv  not in database
# File noaa-gsod-pds/1952/63894099999.csv  not in database
# File noaa-gsod-pds/1952/63962099999.csv  not in database
# File noaa-gsod-pds/1952/63971099999.csv  not in database
# File noaa-gsod-pds/1953/63729099999.csv  not in database
# File noaa-gsod-pds/1953/63733099999.csv  not in database
# File noaa-gsod-pds/1953/63756099999.csv  not in database
# File noaa-gsod-pds/1953/63789099999.csv  not in database
# File noaa-gsod-pds/1953/63791099999.csv  not in database
# File noaa-gsod-pds/1953/63801099999.csv  not in database
# File noaa-gsod-pds/1953/63832099999.csv  not in database
# File noaa-gsod-pds/1953/63845099999.csv  not in database
# File noaa-gsod-pds/1953/63862099999.csv  not in database
# File noaa-gsod-pds/1953/63866099999.csv  not in database
# File noaa-gsod-pds/1953/63870099999.csv  not in database
# File noaa-gsod-pds/1953/63881099999.csv  not in database
# File noaa-gsod-pds/1953/63887099999.csv  not in database
# File noaa-gsod-pds/1953/63894099999.csv  not in database
# File noaa-gsod-pds/1953/63962099999.csv  not in database
# File noaa-gsod-pds/1953/63971099999.csv  not in database
# File noaa-gsod-pds/1954/63729099999.csv  not in database
# File noaa-gsod-pds/1954/63733099999.csv  not in database
# File noaa-gsod-pds/1954/63756099999.csv  not in database
# File noaa-gsod-pds/1954/63789099999.csv  not in database
# File noaa-gsod-pds/1954/63791099999.csv  not in database
# File noaa-gsod-pds/1954/63801099999.csv  not in database
# File noaa-gsod-pds/1954/63832099999.csv  not in database
# File noaa-gsod-pds/1954/63845099999.csv  not in database
# File noaa-gsod-pds/1954/63862099999.csv  not in database
# File noaa-gsod-pds/1954/63866099999.csv  not in database
# File noaa-gsod-pds/1954/63870099999.csv  not in database
# File noaa-gsod-pds/1954/63881099999.csv  not in database
# File noaa-gsod-pds/1954/63887099999.csv  not in database
# File noaa-gsod-pds/1954/63894099999.csv  not in database
# File noaa-gsod-pds/1954/63962099999.csv  not in database
# File noaa-gsod-pds/1954/63971099999.csv  not in database
# File noaa-gsod-pds/1955/63729099999.csv  not in database
# File noaa-gsod-pds/1955/63733099999.csv  not in database
# File noaa-gsod-pds/1955/63756099999.csv  not in database
# File noaa-gsod-pds/1955/63789099999.csv  not in database
# File noaa-gsod-pds/1955/63791099999.csv  not in database
# File noaa-gsod-pds/1955/63801099999.csv  not in database
# File noaa-gsod-pds/1955/63832099999.csv  not in database
# File noaa-gsod-pds/1955/63845099999.csv  not in database
# File noaa-gsod-pds/1955/63862099999.csv  not in database
# File noaa-gsod-pds/1955/63866099999.csv  not in database
# File noaa-gsod-pds/1955/63870099999.csv  not in database
# File noaa-gsod-pds/1955/63881099999.csv  not in database
# File noaa-gsod-pds/1955/63887099999.csv  not in database
# File noaa-gsod-pds/1955/63894099999.csv  not in database
# File noaa-gsod-pds/1955/63962099999.csv  not in database
# File noaa-gsod-pds/1955/63971099999.csv  not in database
# File noaa-gsod-pds/1956/63729099999.csv  not in database
# File noaa-gsod-pds/1956/63733099999.csv  not in database
# File noaa-gsod-pds/1956/63756099999.csv  not in database
# File noaa-gsod-pds/1956/63789099999.csv  not in database
# File noaa-gsod-pds/1956/63791099999.csv  not in database
# File noaa-gsod-pds/1956/63801099999.csv  not in database
# File noaa-gsod-pds/1956/63832099999.csv  not in database
# File noaa-gsod-pds/1956/63845099999.csv  not in database
# File noaa-gsod-pds/1956/63862099999.csv  not in database
# File noaa-gsod-pds/1956/63866099999.csv  not in database
# File noaa-gsod-pds/1956/63870099999.csv  not in database
# File noaa-gsod-pds/1956/63881099999.csv  not in database
# File noaa-gsod-pds/1956/63887099999.csv  not in database
# File noaa-gsod-pds/1956/63894099999.csv  not in database
# File noaa-gsod-pds/1956/63962099999.csv  not in database
# File noaa-gsod-pds/1956/63971099999.csv  not in database
# File noaa-gsod-pds/1957/63729099999.csv  not in database
# File noaa-gsod-pds/1957/63733099999.csv  not in database
# File noaa-gsod-pds/1957/63789099999.csv  not in database
# File noaa-gsod-pds/1957/63791099999.csv  not in database
# File noaa-gsod-pds/1957/63845099999.csv  not in database
# File noaa-gsod-pds/1957/63881099999.csv  not in database
# File noaa-gsod-pds/1958/63729099999.csv  not in database
# File noaa-gsod-pds/1958/63733099999.csv  not in database
# File noaa-gsod-pds/1958/63789099999.csv  not in database
# File noaa-gsod-pds/1958/63791099999.csv  not in database
# File noaa-gsod-pds/1958/63845099999.csv  not in database
# File noaa-gsod-pds/1958/63881099999.csv  not in database
# File noaa-gsod-pds/1959/63729099999.csv  not in database
# File noaa-gsod-pds/1959/63733099999.csv  not in database
# File noaa-gsod-pds/1959/63789099999.csv  not in database
# File noaa-gsod-pds/1959/63791099999.csv  not in database
# File noaa-gsod-pds/1959/63845099999.csv  not in database
# File noaa-gsod-pds/1959/63881099999.csv  not in database
# File noaa-gsod-pds/1960/63791099999.csv  not in database
# File noaa-gsod-pds/1960/63845099999.csv  not in database
# File noaa-gsod-pds/1960/63881099999.csv  not in database
# File noaa-gsod-pds/1961/63791099999.csv  not in database
# File noaa-gsod-pds/1961/63845099999.csv  not in database
# File noaa-gsod-pds/1961/63866099999.csv  not in database
# File noaa-gsod-pds/1961/63881099999.csv  not in database
# File noaa-gsod-pds/1962/63729099999.csv  not in database
# File noaa-gsod-pds/1962/63733099999.csv  not in database
# File noaa-gsod-pds/1962/63756099999.csv  not in database
# File noaa-gsod-pds/1962/63789099999.csv  not in database
# File noaa-gsod-pds/1962/63791099999.csv  not in database
# File noaa-gsod-pds/1962/63801099999.csv  not in database
# File noaa-gsod-pds/1962/63832099999.csv  not in database
# File noaa-gsod-pds/1962/63845099999.csv  not in database
# File noaa-gsod-pds/1962/63862099999.csv  not in database
# File noaa-gsod-pds/1962/63866099999.csv  not in database
# File noaa-gsod-pds/1962/63870099999.csv  not in database
# File noaa-gsod-pds/1962/63881099999.csv  not in database
# File noaa-gsod-pds/1962/63887099999.csv  not in database
# File noaa-gsod-pds/1962/63894099999.csv  not in database
# File noaa-gsod-pds/1962/63962099999.csv  not in database
# File noaa-gsod-pds/1962/63971099999.csv  not in database
# File noaa-gsod-pds/1963/63733099999.csv  not in database
# File noaa-gsod-pds/1963/63791099999.csv  not in database
# File noaa-gsod-pds/1963/63801099999.csv  not in database
# File noaa-gsod-pds/1963/63832099999.csv  not in database
# File noaa-gsod-pds/1963/63845099999.csv  not in database
# File noaa-gsod-pds/1963/63862099999.csv  not in database
# File noaa-gsod-pds/1963/63866099999.csv  not in database
# File noaa-gsod-pds/1963/63870099999.csv  not in database
# File noaa-gsod-pds/1963/63881099999.csv  not in database
# File noaa-gsod-pds/1963/63887099999.csv  not in database
# File noaa-gsod-pds/1964/63733099999.csv  not in database
# File noaa-gsod-pds/1964/63791099999.csv  not in database
# File noaa-gsod-pds/1964/63801099999.csv  not in database
# File noaa-gsod-pds/1964/63832099999.csv  not in database
# File noaa-gsod-pds/1964/63845099999.csv  not in database
# File noaa-gsod-pds/1964/63862099999.csv  not in database
# File noaa-gsod-pds/1964/63866099999.csv  not in database
# File noaa-gsod-pds/1964/63870099999.csv  not in database
# File noaa-gsod-pds/1964/63881099999.csv  not in database
# File noaa-gsod-pds/1964/63887099999.csv  not in database
# File noaa-gsod-pds/1965/63733099999.csv  not in database
# File noaa-gsod-pds/1965/63791099999.csv  not in database
# File noaa-gsod-pds/1965/63801099999.csv  not in database
# File noaa-gsod-pds/1965/63832099999.csv  not in database
# File noaa-gsod-pds/1965/63845099999.csv  not in database
# File noaa-gsod-pds/1965/63862099999.csv  not in database
# File noaa-gsod-pds/1965/63866099999.csv  not in database
# File noaa-gsod-pds/1965/63870099999.csv  not in database
# File noaa-gsod-pds/1965/63881099999.csv  not in database
# File noaa-gsod-pds/1965/63887099999.csv  not in database
# File noaa-gsod-pds/1966/63733099999.csv  not in database
# File noaa-gsod-pds/1966/63791099999.csv  not in database
# File noaa-gsod-pds/1966/63801099999.csv  not in database
# File noaa-gsod-pds/1966/63832099999.csv  not in database
# File noaa-gsod-pds/1966/63845099999.csv  not in database
# File noaa-gsod-pds/1966/63862099999.csv  not in database
# File noaa-gsod-pds/1966/63866099999.csv  not in database
# File noaa-gsod-pds/1966/63870099999.csv  not in database
# File noaa-gsod-pds/1966/63881099999.csv  not in database
# File noaa-gsod-pds/1966/63887099999.csv  not in database
# File noaa-gsod-pds/1967/63729099999.csv  not in database
# File noaa-gsod-pds/1967/63733099999.csv  not in database
# File noaa-gsod-pds/1967/63756099999.csv  not in database
# File noaa-gsod-pds/1967/63789099999.csv  not in database
# File noaa-gsod-pds/1967/63791099999.csv  not in database
# File noaa-gsod-pds/1967/63801099999.csv  not in database
# File noaa-gsod-pds/1967/63832099999.csv  not in database
# File noaa-gsod-pds/1967/63845099999.csv  not in database
# File noaa-gsod-pds/1967/63862099999.csv  not in database
# File noaa-gsod-pds/1967/63866099999.csv  not in database
# File noaa-gsod-pds/1967/63870099999.csv  not in database
# File noaa-gsod-pds/1967/63881099999.csv  not in database
# File noaa-gsod-pds/1967/63887099999.csv  not in database
# File noaa-gsod-pds/1967/63894099999.csv  not in database
# File noaa-gsod-pds/1967/63962099999.csv  not in database
# File noaa-gsod-pds/1967/63971099999.csv  not in database
# File noaa-gsod-pds/1968/63729099999.csv  not in database
# File noaa-gsod-pds/1968/63733099999.csv  not in database
# File noaa-gsod-pds/1968/63756099999.csv  not in database
# File noaa-gsod-pds/1968/63789099999.csv  not in database
# File noaa-gsod-pds/1968/63791099999.csv  not in database
# File noaa-gsod-pds/1968/63801099999.csv  not in database
# File noaa-gsod-pds/1968/63832099999.csv  not in database
# File noaa-gsod-pds/1968/63845099999.csv  not in database
# File noaa-gsod-pds/1968/63862099999.csv  not in database
# File noaa-gsod-pds/1968/63866099999.csv  not in database
# File noaa-gsod-pds/1968/63870099999.csv  not in database
# File noaa-gsod-pds/1968/63881099999.csv  not in database
# File noaa-gsod-pds/1968/63887099999.csv  not in database
# File noaa-gsod-pds/1968/63894099999.csv  not in database
# File noaa-gsod-pds/1968/63962099999.csv  not in database
# File noaa-gsod-pds/1968/63971099999.csv  not in database
# File noaa-gsod-pds/1969/63729099999.csv  not in database
# File noaa-gsod-pds/1969/63733099999.csv  not in database
# File noaa-gsod-pds/1969/63756099999.csv  not in database
# File noaa-gsod-pds/1969/63789099999.csv  not in database
# File noaa-gsod-pds/1969/63791099999.csv  not in database
# File noaa-gsod-pds/1969/63801099999.csv  not in database
# File noaa-gsod-pds/1969/63832099999.csv  not in database
# File noaa-gsod-pds/1969/63845099999.csv  not in database
# File noaa-gsod-pds/1969/63862099999.csv  not in database
# File noaa-gsod-pds/1969/63866099999.csv  not in database
# File noaa-gsod-pds/1969/63870099999.csv  not in database
# File noaa-gsod-pds/1969/63881099999.csv  not in database
# File noaa-gsod-pds/1969/63887099999.csv  not in database
# File noaa-gsod-pds/1969/63894099999.csv  not in database
# File noaa-gsod-pds/1969/63962099999.csv  not in database
# File noaa-gsod-pds/1969/63971099999.csv  not in database
# File noaa-gsod-pds/1970/63729099999.csv  not in database
# File noaa-gsod-pds/1970/63733099999.csv  not in database
# File noaa-gsod-pds/1970/63756099999.csv  not in database
# File noaa-gsod-pds/1970/63789099999.csv  not in database
# File noaa-gsod-pds/1970/63791099999.csv  not in database
# File noaa-gsod-pds/1970/63801099999.csv  not in database
# File noaa-gsod-pds/1970/63832099999.csv  not in database
# File noaa-gsod-pds/1970/63845099999.csv  not in database
# File noaa-gsod-pds/1970/63862099999.csv  not in database
# File noaa-gsod-pds/1970/63866099999.csv  not in database
# File noaa-gsod-pds/1970/63870099999.csv  not in database
# File noaa-gsod-pds/1970/63881099999.csv  not in database
# File noaa-gsod-pds/1970/63887099999.csv  not in database
# File noaa-gsod-pds/1970/63894099999.csv  not in database
# File noaa-gsod-pds/1970/63962099999.csv  not in database
# File noaa-gsod-pds/1970/63971099999.csv  not in database
# File noaa-gsod-pds/1971/63729099999.csv  not in database
# File noaa-gsod-pds/1971/63733099999.csv  not in database
# File noaa-gsod-pds/1971/63756099999.csv  not in database
# File noaa-gsod-pds/1971/63789099999.csv  not in database
# File noaa-gsod-pds/1971/63791099999.csv  not in database
# File noaa-gsod-pds/1971/63801099999.csv  not in database
# File noaa-gsod-pds/1971/63832099999.csv  not in database
# File noaa-gsod-pds/1971/63845099999.csv  not in database
# File noaa-gsod-pds/1971/63862099999.csv  not in database
# File noaa-gsod-pds/1971/63866099999.csv  not in database
# File noaa-gsod-pds/1971/63870099999.csv  not in database
# File noaa-gsod-pds/1971/63881099999.csv  not in database
# File noaa-gsod-pds/1971/63887099999.csv  not in database
# File noaa-gsod-pds/1971/63894099999.csv  not in database
# File noaa-gsod-pds/1971/63962099999.csv  not in database
# File noaa-gsod-pds/1971/63971099999.csv  not in database
# File noaa-gsod-pds/1972/63729099999.csv  not in database
# File noaa-gsod-pds/1972/63733099999.csv  not in database
# File noaa-gsod-pds/1972/63756099999.csv  not in database
# File noaa-gsod-pds/1972/63789099999.csv  not in database
# File noaa-gsod-pds/1972/63791099999.csv  not in database
# File noaa-gsod-pds/1972/63801099999.csv  not in database
# File noaa-gsod-pds/1972/63832099999.csv  not in database
# File noaa-gsod-pds/1972/63845099999.csv  not in database
# File noaa-gsod-pds/1972/63862099999.csv  not in database
# File noaa-gsod-pds/1972/63866099999.csv  not in database
# File noaa-gsod-pds/1972/63870099999.csv  not in database
# File noaa-gsod-pds/1972/63881099999.csv  not in database
# File noaa-gsod-pds/1972/63887099999.csv  not in database
# File noaa-gsod-pds/1972/63894099999.csv  not in database
# File noaa-gsod-pds/1972/63962099999.csv  not in database
# File noaa-gsod-pds/1972/63971099999.csv  not in database
# File noaa-gsod-pds/1973/63733099999.csv  not in database
# File noaa-gsod-pds/1973/63845099999.csv  not in database
# File noaa-gsod-pds/1973/63881099999.csv  not in database
# File noaa-gsod-pds/1974/63729099999.csv  not in database
# File noaa-gsod-pds/1974/63733099999.csv  not in database
# File noaa-gsod-pds/1974/63845099999.csv  not in database
# File noaa-gsod-pds/1974/63881099999.csv  not in database
# File noaa-gsod-pds/1975/63881099999.csv  not in database
# File noaa-gsod-pds/1976/63881099999.csv  not in database
# File noaa-gsod-pds/1977/63881099999.csv  not in database
# File noaa-gsod-pds/1978/63881099999.csv  not in database
# File noaa-gsod-pds/1979/63881099999.csv  not in database
# File noaa-gsod-pds/1980/63881099999.csv  not in database
# File noaa-gsod-pds/1981/63881099999.csv  not in database
# File noaa-gsod-pds/1982/63845099999.csv  not in database
# File noaa-gsod-pds/1982/63881099999.csv  not in database
# File noaa-gsod-pds/1983/63881099999.csv  not in database
# File noaa-gsod-pds/1984/63881099999.csv  not in database
# File noaa-gsod-pds/1984/63887099999.csv  not in database
# File noaa-gsod-pds/1985/63881099999.csv  not in database
# File noaa-gsod-pds/1986/63881099999.csv  not in database
# File noaa-gsod-pds/1987/63881099999.csv  not in database
# File noaa-gsod-pds/1988/63881099999.csv  not in database
# File noaa-gsod-pds/1991/63845099999.csv  not in database
# File noaa-gsod-pds/1992/63845099999.csv  not in database
# File noaa-gsod-pds/1993/63881099999.csv  not in database
# File noaa-gsod-pds/1994/63881099999.csv  not in database
# File noaa-gsod-pds/1995/63881099999.csv  not in database
# File noaa-gsod-pds/1996/63881099999.csv  not in database
# File noaa-gsod-pds/1997/63881099999.csv  not in database
# File noaa-gsod-pds/1998/63881099999.csv  not in database
# File noaa-gsod-pds/1999/63789099999.csv  not in database
# File noaa-gsod-pds/1999/63801099999.csv  not in database
# File noaa-gsod-pds/1999/63881099999.csv  not in database
# File noaa-gsod-pds/2000/63881099999.csv  not in database
# File noaa-gsod-pds/2002/63789099999.csv  not in database
# File noaa-gsod-pds/2002/63845099999.csv  not in database
# File noaa-gsod-pds/2003/63789099999.csv  not in database
# File noaa-gsod-pds/2003/63845099999.csv  not in database
# File noaa-gsod-pds/2008/63845099999.csv  not in database
# File noaa-gsod-pds/2009/63845099999.csv  not in database
# File noaa-gsod-pds/2010/63845099999.csv  not in database
# File noaa-gsod-pds/2011/63845099999.csv  not in database
# File noaa-gsod-pds/2014/63729099999.csv  not in database
# File noaa-gsod-pds/2014/63845099999.csv  not in database
# File noaa-gsod-pds/2015/63845099999.csv  not in database
# File noaa-gsod-pds/2016/63845099999.csv  not in database
# File noaa-gsod-pds/2017/63845099999.csv  not in database
# File noaa-gsod-pds/2018/63845099999.csv  not in database
# File noaa-gsod-pds/2019/63845099999.csv  not in database
# File noaa-gsod-pds/2020/63845099999.csv  not in database
# File noaa-gsod-pds/2021/63845099999.csv  not in database
# File noaa-gsod-pds/2022/63845099999.csv  not in database
# File noaa-gsod-pds/2023/63845099999.csv  not in database
# 622.0166742801666

# %% [markdown]
# ### ~10 min. Much better, no?

# %%
# Let's concatenate all the data frames in dfs
gsod_tz = pd.concat(dfs, ignore_index=True)

# %%
# Let's save the data frame as .csv
gsod_tz.to_csv("../data/noaa.gsod-pds.csv")
